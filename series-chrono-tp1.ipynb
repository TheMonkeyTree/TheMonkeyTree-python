# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <h1>TP 1 - Décomposition d’une série</h1>
# <h2>Exercice 1.</h2>
# <p>Examen Avril 2017 version modifiée). Le chiffre d’affaires (enregistré le 31 décembre 2016) d’un magasin sur 3 années est donné par le tableau suivant</p>
# <table>
#    <tr>
#        <th>Trimestre/Année</th>
#        <th>2014</th>
#        <th>2015</th>
#         <th>2016</th>
#    </tr>
#    <tr>
#        <td>T1</td>
#        <td>2250</td>
#        <td>1893</td>
#         <td>2140</td>
#    </tr>
#      <tr>
#        <td>T2</td>
#        <td>2394</td>
#        <td>2067</td>
#         <td>2458</td>
#    </tr>
#      <tr>
#        <td>T3</td>
#        <td>2059</td>
#        <td>2120</td>
#         <td>2226</td>
#    </tr>
#      <tr>
#        <td>T4</td>
#        <td>4161</td>
#        <td>3936</td>
#         <td>4092</td>
#    </tr>
# </table>

# %%
data = np.array([2250 ,2394 ,2059,4161 ,1893,2067,2120,3936,2140,2458,2226,4092])
graph = plt.plot(data)

# %% [markdown]
# <p>1. Appliquer le test de Buys-Ballot pour décider si le modèle est additif ou multiplicatif.</p>

# %%
# test de Buys-Ballot
n=12
r=4
N=n/r
A = data.reshape(3,4)
print(A)

# %% [markdown]
# <p>2. Pour modéliser cette chronique (que l’on note par $x_t$ ) on propose le modèle suivant
# $$X_t = m_t+S_t+\epsilon_t;\quad t\in \{1,...,T\}$$
# $m_t$ est la tendance<br>
# $S_t$ est la composante saisonnière<br>
# La moyenne empirique de la chronique est donnée par :
#     $$
#     \overline{X}_T = \frac{1}{T}\sum_{t=1}^{T}X_t = 2649.67
#     $$
# </p>
# <p>Montrer que $m_t=m$<br>
# i.e. : la chronique est stable</p>

# %% [markdown]
# <p>3. On se propose de modéliser la composante saisonnière par la méthode des moyennes saisonnières.<br>
# Pour calculer les coefficients saisoniers, on se base sur la série $X_t$ (et non pas sur la série $W_t = X_t − m_t$ ).<br>
# Le tableau suivant donne les trois premiers coefficients saisoniers avant normalisation :
#     <table>
#    <tr>
#        <th>$S_1'$</th>
#        <th>$S_2'$</th>
#        <th>$S_3'$</th>
#         <th>$S_4'$</th>
#    </tr>
#    <tr>
#        <td>2094.33</td>
#        <td>2306.33</td>
#        <td>2135</td>
#         <td></td>
#    </tr>
# </table>
#     Calculer $S_4'$ et puis les coefficients saisonniers normalisés $S_i, i = 1, .., 4$.
#     </p>

# %% [markdown]
# <p>4. Montrer que si on se base sur la série $W_t = X_t − m_t$ pour calculer les coefficients saisoniers alors ceux-ci sont automatiquement normalisés.</p>

# %% [markdown]
# <p>5. Donner une prévision du chiffre d’affaires pour les quatre trimestres de l’année 2017.</p>
